# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Electric_Vehicle_Population_Data.csv")

# %%
df.head()
# Out:
#    VIN (1-10)    County     City State  Postal Code  Model Year    Make  \
# 0  5YJXCAE26J    Yakima   Yakima    WA      98908.0        2018   TESLA
# 1  JHMZC5F37M    Kitsap  Poulsbo    WA      98370.0        2021   HONDA
# 2  5YJ3E1EB0K      King  Seattle    WA      98199.0        2019   TESLA
# 3  1N4AZ0CP5D      King  Seattle    WA      98119.0        2013  NISSAN
# 4  5YJSA1E21H  Thurston    Lacey    WA      98516.0        2017   TESLA
#
#      Model                   Electric Vehicle Type  \
# 0  MODEL X          Battery Electric Vehicle (BEV)
# 1  CLARITY  Plug-in Hybrid Electric Vehicle (PHEV)
# 2  MODEL 3          Battery Electric Vehicle (BEV)
# 3     LEAF          Battery Electric Vehicle (BEV)
# 4  MODEL S          Battery Electric Vehicle (BEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0           Clean Alternative Fuel Vehicle Eligible             238
# 1           Clean Alternative Fuel Vehicle Eligible              47
# ...

# %%
df[df['City'] == 'Bothell']
# Out:
#         VIN (1-10)     County     City State  Postal Code  Model Year  \
# 36      KNDRJDLH1N  Snohomish  Bothell    WA      98021.0        2022
# 39      5YJ3E1EA6L  Snohomish  Bothell    WA      98012.0        2020
# 56      1N4BZ0CPXH  Snohomish  Bothell    WA      98021.0        2017
# 217     5YJ3E1EB9N       King  Bothell    WA      98011.0        2022
# 218     7SAYGDEEXN  Snohomish  Bothell    WA      98012.0        2022
# ...            ...        ...      ...   ...          ...         ...
# 130001  1FMCU0KZ7N  Snohomish  Bothell    WA      98012.0        2022
# 130074  KNDCE3LG4N  Snohomish  Bothell    WA      98021.0        2022
# 130177  2C4RC1L71J  Snohomish  Bothell    WA      98012.0        2018
# 130295  5YJ3E1EA8N  Snohomish  Bothell    WA      98021.0        2022
# 130392  5YJ3E1EA9J       King  Bothell    WA      98011.0        2018
#
#             Make     Model                   Electric Vehicle Type  \
# ...

# %% [markdown]
# ## Data analysis

# %%
tesla_bothell_cars = df[(df['Make'] == 'TESLA') & (df['City'] == 'Bothell')]

# %%
tesla_bothell_cars
# Out:
#         VIN (1-10)     County     City State  Postal Code  Model Year   Make  \
# 39      5YJ3E1EA6L  Snohomish  Bothell    WA      98012.0        2020  TESLA
# 217     5YJ3E1EB9N       King  Bothell    WA      98011.0        2022  TESLA
# 218     7SAYGDEEXN  Snohomish  Bothell    WA      98012.0        2022  TESLA
# 222     5YJ3E1EB6J       King  Bothell    WA      98011.0        2018  TESLA
# 292     5YJXCBE40H       King  Bothell    WA      98011.0        2017  TESLA
# ...            ...        ...      ...   ...          ...         ...    ...
# 129778  5YJ3E1EB3K  Snohomish  Bothell    WA      98012.0        2019  TESLA
# 129954  5YJ3E1EB3M  Snohomish  Bothell    WA      98021.0        2021  TESLA
# 129976  5YJSA1S10E  Snohomish  Bothell    WA      98021.0        2014  TESLA
# 130295  5YJ3E1EA8N  Snohomish  Bothell    WA      98021.0        2022  TESLA
# 130392  5YJ3E1EA9J       King  Bothell    WA      98011.0        2018  TESLA
#
# ...

# %%
tesla_bothell_cars.rename(columns={'Model Year':'Model_Year'},inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_23808\427663105.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tesla_bothell_cars.rename(columns={'Model Year':'Model_Year'},inplace=True)

# %%
tesla_bothell_cars
# Out:
#         VIN (1-10)     County     City State  Postal Code  Model_Year   Make  \
# 39      5YJ3E1EA6L  Snohomish  Bothell    WA      98012.0        2020  TESLA
# 217     5YJ3E1EB9N       King  Bothell    WA      98011.0        2022  TESLA
# 218     7SAYGDEEXN  Snohomish  Bothell    WA      98012.0        2022  TESLA
# 222     5YJ3E1EB6J       King  Bothell    WA      98011.0        2018  TESLA
# 292     5YJXCBE40H       King  Bothell    WA      98011.0        2017  TESLA
# ...            ...        ...      ...   ...          ...         ...    ...
# 129778  5YJ3E1EB3K  Snohomish  Bothell    WA      98012.0        2019  TESLA
# 129954  5YJ3E1EB3M  Snohomish  Bothell    WA      98021.0        2021  TESLA
# 129976  5YJSA1S10E  Snohomish  Bothell    WA      98021.0        2014  TESLA
# 130295  5YJ3E1EA8N  Snohomish  Bothell    WA      98021.0        2022  TESLA
# 130392  5YJ3E1EA9J       King  Bothell    WA      98011.0        2018  TESLA
#
# ...

# %%
columns_name = ['Model_Year','Model']

# %%
tesla = tesla_bothell_cars[columns_name]

# %%
tesla.head()
# Out:
#      Model_Year    Model
# 39         2020  MODEL 3
# 217        2022  MODEL 3
# 218        2022  MODEL Y
# 222        2018  MODEL 3
# 292        2017  MODEL X

# %% [markdown]
#  ## Get all the cars that have an electric range of more than 100, and were made after 2015

# %%
df["Electric Vehicle Type"].unique()
# Out:
# array(['Battery Electric Vehicle (BEV)',
#        'Plug-in Hybrid Electric Vehicle (PHEV)'], dtype=object)

# %%
 electric_vechiles = df[df["Electric Vehicle Type"]=="Battery Electric Vehicle (BEV)"]

# %%
electric_vechiles
# Out:
#         VIN (1-10)    County           City State  Postal Code  Model Year  \
# 0       5YJXCAE26J    Yakima         Yakima    WA      98908.0        2018
# 2       5YJ3E1EB0K      King        Seattle    WA      98199.0        2019
# 3       1N4AZ0CP5D      King        Seattle    WA      98119.0        2013
# 4       5YJSA1E21H  Thurston          Lacey    WA      98516.0        2017
# 9       5YJSA1CP1D    Kitsap      Bremerton    WA      98312.0        2013
# ...            ...       ...            ...   ...          ...         ...
# 130438  7SAYGDEE6P    Pierce     Gig Harbor    WA      98335.0        2023
# 130439  1N4BZ1CV7N    Pierce         Tacoma    WA      98408.0        2022
# 130440  5YJYGDEE8M      King        Seattle    WA      98109.0        2021
# 130441  5YJXCBE22L    Island  Camano Island    WA      98282.0        2020
# 130442  5YJ3E1EA5M    Pierce       Puyallup    WA      98375.0        2021
#
#           Make    Model           Electric Vehicle Type  \
# ...

# %%
range_100andyearafter2015 = electric_vechiles[(electric_vechiles['Electric Range'] > 100) & (electric_vechiles['Model Year'] > 2015)]

# %%
range_100andyearafter2015
# Out:
#         VIN (1-10)    County           City State  Postal Code  Model Year  \
# 0       5YJXCAE26J    Yakima         Yakima    WA      98908.0        2018
# 2       5YJ3E1EB0K      King        Seattle    WA      98199.0        2019
# 4       5YJSA1E21H  Thurston          Lacey    WA      98516.0        2017
# 12      5YJ3E1EC7L  Thurston          Lacey    WA      98503.0        2020
# 13      5YJ3E1EB2L  Thurston        Olympia    WA      98516.0        2020
# ...            ...       ...            ...   ...          ...         ...
# 130417  5YJYGDEE5L    Pierce         Tacoma    WA      98444.0        2020
# 130428  1N4AZ1CP0J   Clallam         Sequim    WA      98382.0        2018
# 130432  5YJYGDEEXL      King         Vashon    WA      98070.0        2020
# 130436  5YJ3E1EB0J   Whatcom         Blaine    WA      98230.0        2018
# 130441  5YJXCBE22L    Island  Camano Island    WA      98282.0        2020
#
#           Make    Model           Electric Vehicle Type  \
# ...

# %% [markdown]
# ## Get all the cars and their types that do not qualify for clean alternative fuel vehicle

# %%
df['Clean Alternative Fuel Vehicle (CAFV) Eligibility'].unique()
# Out:
# array(['Clean Alternative Fuel Vehicle Eligible',
#        'Not eligible due to low battery range',
#        'Eligibility unknown as battery range has not been researched'],
#       dtype=object)

# %%
not_elibible_for_eligible = df[df['Clean Alternative Fuel Vehicle (CAFV) Eligibility']== 'Not eligible due to low battery range']

# %%
not_elibible_for_eligible.head()
# Out:
#     VIN (1-10)    County               City State  Postal Code  Model Year  \
# 6   3FA6P0PU1G  Thurston           Tumwater    WA      98501.0        2016
# 7   WA1F2AFY8P  Thurston              Lacey    WA      98516.0        2023
# 8   1FADP5CU0E  Thurston          Rochester    WA      98579.0        2014
# 14  1FADP5FU4H  Thurston              Lacey    WA      98513.0        2017
# 15  KNDCM3LD8L    Kitsap  Bainbridge Island    WA      98110.0        2020
#
#     Make   Model                   Electric Vehicle Type  \
# 6   FORD  FUSION  Plug-in Hybrid Electric Vehicle (PHEV)
# 7   AUDI    Q5 E  Plug-in Hybrid Electric Vehicle (PHEV)
# 8   FORD   C-MAX  Plug-in Hybrid Electric Vehicle (PHEV)
# 14  FORD   C-MAX  Plug-in Hybrid Electric Vehicle (PHEV)
# 15   KIA    NIRO  Plug-in Hybrid Electric Vehicle (PHEV)
#
#    Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 6              Not eligible due to low battery range              19
# ...

# %% [markdown]
# ## ● Draw plots to show the distribution between city and electric vehicle type

# %%
city = df['City'].value_counts()

# %%
city
# Out:
# Seattle        22894
# Bellevue        6748
# Redmond         4820
# Vancouver       4652
# Kirkland        4071
#                ...
# Asheboro           1
# Germantown         1
# Saint Jacob        1
# Watertown          1
# Aurora             1
# Name: City, Length: 656, dtype: int64
