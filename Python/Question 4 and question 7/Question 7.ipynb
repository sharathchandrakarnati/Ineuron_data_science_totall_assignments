# %% [markdown]
# ## ● Get all the Earth meteorites that fell before the year 2000
# ## ● Get all the earth meteorites co-ordinates who fell before the year 1970
# ## ● Assuming that the mass of the earth meteorites was in kg, get all those whose mass was more than 10000kg

# %%
import pandas as pd
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("program_5.csv")

# %%
df.head()
# Out:
#        name   id nametype     recclass      mass  fall  \
# 0    Aachen    1    Valid           L5      21.0  Fell
# 1    Aarhus    2    Valid           H6     720.0  Fell
# 2      Abee    6    Valid          EH4  107000.0  Fell
# 3  Acapulco   10    Valid  Acapulcoite    1914.0  Fell
# 4   Achiras  370    Valid           L6     780.0  Fell
#
#                       year    reclat    reclong geolocation.type  \
# 0  1880-01-01T00:00:00.000  50.77500    6.08333            Point
# 1  1951-01-01T00:00:00.000  56.18333   10.23333            Point
# 2  1952-01-01T00:00:00.000  54.21667 -113.00000            Point
# 3  1976-01-01T00:00:00.000  16.88333  -99.90000            Point
# 4  1902-01-01T00:00:00.000 -33.16667  -64.95000            Point
#
#   geolocation.coordinates  :@computed_region_cbhk_fwbd  \
# 0       [6.08333, 50.775]                          NaN
# 1    [10.23333, 56.18333]                          NaN
# 2        [-113, 54.21667]                          NaN
# ...

# %%
df.columns
# Out:
# Index(['name', 'id', 'nametype', 'recclass', 'mass', 'fall', 'year', 'reclat',
#        'reclong', 'geolocation.type', 'geolocation.coordinates',
#        ':@computed_region_cbhk_fwbd', ':@computed_region_nnqa_25f4'],
#       dtype='object')

# %%
df.drop([':@computed_region_cbhk_fwbd', ':@computed_region_nnqa_25f4'],axis=1, inplace=True)

# %%
df
# Out:
#           name     id nametype               recclass      mass  fall  \
# 0       Aachen      1    Valid                     L5      21.0  Fell
# 1       Aarhus      2    Valid                     H6     720.0  Fell
# 2         Abee      6    Valid                    EH4  107000.0  Fell
# 3     Acapulco     10    Valid            Acapulcoite    1914.0  Fell
# 4      Achiras    370    Valid                     L6     780.0  Fell
# ..         ...    ...      ...                    ...       ...   ...
# 995   Tirupati  24009    Valid                     H6     230.0  Fell
# 996    Tissint  54823    Valid  Martian (shergottite)    7000.0  Fell
# 997      Tjabe  24011    Valid                     H6   20000.0  Fell
# 998   Tjerebon  24012    Valid                     L5   16500.0  Fell
# 999  Tomakovka  24019    Valid                    LL6     600.0  Fell
#
#                         year    reclat    reclong geolocation.type  \
# ...

# %% [markdown]
# ## data analysis

# %%
data_analysis_3 = df[df['mass']>10000]

# %%
data_analysis_3
# Out:
#            name     id nametype   recclass      mass  fall  \
# 2          Abee      6    Valid        EH4  107000.0  Fell
# 7          Agen    392    Valid         H5   30000.0  Fell
# 11          Aïr    424    Valid         L6   24000.0  Fell
# 16      Akyumak    433    Valid  Iron, IVA   50000.0  Fell
# 27   Alfianello    466    Valid         L6  228000.0  Fell
# ..          ...    ...      ...        ...       ...   ...
# 991   Tieschitz  23989    Valid     H/L3.6   28000.0  Fell
# 992      Tilden  23998    Valid         L6   74800.0  Fell
# 994    Timochin  24004    Valid         H5   65500.0  Fell
# 997       Tjabe  24011    Valid         H6   20000.0  Fell
# 998    Tjerebon  24012    Valid         L5   16500.0  Fell
#
#                         year    reclat    reclong geolocation.type  \
# 2    1952-01-01T00:00:00.000  54.21667 -113.00000            Point
# 7    1814-01-01T00:00:00.000  44.21667    0.61667            Point
# ...

# %%
data_analysis_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 243 entries, 2 to 998
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   name                     243 non-null    object
#  1   id                       243 non-null    int64
#  2   nametype                 243 non-null    object
#  3   recclass                 243 non-null    object
#  4   mass                     243 non-null    float64
#  5   fall                     243 non-null    object
#  6   year                     243 non-null    object
#  7   reclat                   243 non-null    float64
#  8   reclong                  243 non-null    float64
#  9   geolocation.type         243 non-null    object
#  10  geolocation.coordinates  243 non-null    object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 22.8+ KB

# %%
sns.distplot([data_analysis_3['mass']])
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
df['years'] = df['year'].str[:4]

# %%
df
# Out:
#           name     id nametype               recclass      mass  fall  \
# 0       Aachen      1    Valid                     L5      21.0  Fell
# 1       Aarhus      2    Valid                     H6     720.0  Fell
# 2         Abee      6    Valid                    EH4  107000.0  Fell
# 3     Acapulco     10    Valid            Acapulcoite    1914.0  Fell
# 4      Achiras    370    Valid                     L6     780.0  Fell
# ..         ...    ...      ...                    ...       ...   ...
# 995   Tirupati  24009    Valid                     H6     230.0  Fell
# 996    Tissint  54823    Valid  Martian (shergottite)    7000.0  Fell
# 997      Tjabe  24011    Valid                     H6   20000.0  Fell
# 998   Tjerebon  24012    Valid                     L5   16500.0  Fell
# 999  Tomakovka  24019    Valid                    LL6     600.0  Fell
#
#                         year    reclat    reclong geolocation.type  \
# ...

# %% [markdown]
# ## ● Get all the Earth meteorites that fell before the year 2000

# %%
df_falls_year_2000 = df[df['years']<'2000']

# %%
df_falls_year_2000
# Out:
#           name     id nametype     recclass      mass  fall  \
# 0       Aachen      1    Valid           L5      21.0  Fell
# 1       Aarhus      2    Valid           H6     720.0  Fell
# 2         Abee      6    Valid          EH4  107000.0  Fell
# 3     Acapulco     10    Valid  Acapulcoite    1914.0  Fell
# 4      Achiras    370    Valid           L6     780.0  Fell
# ..         ...    ...      ...          ...       ...   ...
# 994   Timochin  24004    Valid           H5   65500.0  Fell
# 995   Tirupati  24009    Valid           H6     230.0  Fell
# 997      Tjabe  24011    Valid           H6   20000.0  Fell
# 998   Tjerebon  24012    Valid           L5   16500.0  Fell
# 999  Tomakovka  24019    Valid          LL6     600.0  Fell
#
#                         year    reclat    reclong geolocation.type  \
# 0    1880-01-01T00:00:00.000  50.77500    6.08333            Point
# 1    1951-01-01T00:00:00.000  56.18333   10.23333            Point
# ...

# %%
sns.distplot(df_falls_year_2000['years'])
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='years', ylabel='Density'>

# %% [markdown]
# ## ● Get all the earth meteorites co-ordinates who fell before the year 1970

# %%
df_falls_year_1970 = df[df['years']<'1970']

# %%
sns.distplot(df_falls_year_1970['years'])
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='years', ylabel='Density'>
